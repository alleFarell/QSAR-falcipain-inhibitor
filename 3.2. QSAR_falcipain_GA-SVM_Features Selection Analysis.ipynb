# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
"""
Selected features GA are devided for each SVR kernel

index
0: linear kernel
1: rbf kernel
2: poly kernel


Each kernel should has 20 different results from 20 different runtimes

By calling 'best_solution' we're accessing the best result of all runtimes
"""
# Out:
# "\nSelected features GA are devided for each SVR kernel\n\nindex\n0: linear kernel\n1: rbf kernel\n2: poly kernel\n\n\nEach kernel should has 20 different results from 20 different runtimes\n\nBy calling 'best_solution' we're accessing the best result of all runtimes\n"

# %% [markdown]
# # Load GA FS Result in Pickle

# %%
GA_result = joblib.load('Dataset Falcipain/selected_features_GA.pkl')
GA_result
# Out:
# [{1: {'score': 0.5308105032387859,
#    'num_features': 270,
#    'selected_features': ['ALogP',
#     'ALogp2',
#     'AMR',
#     'apol',
#     'naAromAtom',
#     'nAromBond',
#     'nAtom',
#     'nH',
#     'nC',
#     'nN',
#     'nS',
#     'ATS3m',
#     'ATS4m',
#     'ATS7m',
#     'ATS0v',
#     'ATS1v',
#     'ATS3v',
#     'ATS5v',
#     'ATS7v',
#     'ATS0e',
#     'ATS2e',
#     'ATS3e',
#     'ATS1p',
#     'ATS3p',
#     'ATS6p',
#     'ATS7p',
#     'ATS3i',
#     'ATS5i',
#     'ATS7i',
#     'ATS8i',
#     'ATS0s',
#     'ATS4s',
#     'ATS5s',
#     'AATS1m',
#     'AATS5m',
#     'AATS7m',
#     'AATS8m',
#     'AATS0v',
#     'AATS1v',
#     'AATS7v',
#     'AATS8v',
#     'AATS2i',
#     'AATS3i',
#     'AATS4i',
#     'AATS8i',
#     'AATS2s',
#     'AATS4s',
#     'AATS5s',
#     'AATS6s',
#     'AATS8s',
#     'ATSC0m',
#     'ATSC1m',
#     'ATSC2m',
#     'ATSC3m',
#     'ATSC4m',
#     'ATSC5m',
#     'ATSC6m',
#     'ATSC1v',
#     'ATSC2v',
# ...

# %% [markdown]
# # Convert Result to Datafarame for Analysis

# %%
GA_result[0][1].keys()
# Out:
# dict_keys(['score', 'num_features', 'selected_features', 'plot'])

# %%
pd.DataFrame.from_dict(GA_result[0])
# GA_result[0][1]
# Out:
#                                                                    1  \
# score                                                       0.530811
# num_features                                                     270
# selected_features  [ALogP, ALogp2, AMR, apol, naAromAtom, nAromBo...
# plot               Figure({\n    'data': [{'mode': 'markers',\n  ...
# run_id                                                           NaN
# best_score                                                       NaN
#
#                                                                    2  \
# score                                                       0.543333
# num_features                                                     260
# selected_features  [ALogP, nAtom, nH, nX, ATS2m, ATS4m, ATS6m, AT...
# plot               Figure({\n    'data': [{'mode': 'markers',\n  ...
# run_id                                                           NaN
# ...

# %%
GA_linear =
