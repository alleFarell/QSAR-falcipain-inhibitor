# %%
import pandas as pd
import numpy as np
import re

# %%
raw_data = pd.read_csv("D:\Coding\Machine Learning\Bioinformatics\QSAR study on falcipain inhibitor\Dataset Falciapin\Data_Sheet_1_In_silico_Guided_Drug_Repurposing_Discovery_of_New.CSV", sep=";")
raw_data
# Out:
#      Compound                                             SMILE  \
# 0           2    OCCCc1sc(\C=C\C(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 1           3       OCCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 2           4      O=CCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 3           5   CC(=O)OCc1nc(CCC(=O)CSCCCc2ccccc2)sc1CCc1ccccc1
# 4           6   NC(=O)CCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# ..        ...                                               ...
# 510       575     Oc1cc(O)c2c(c1)oc(-c1cc(O)c(O)c(O)c1)c(O)c2=O
# 511       576        Oc1cc(O)c2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O
# 512       577          Oc1ccc(c(O)c1)-c1oc2cc(O)cc(O)c2c(=O)c1O
# 513       578  O[C@@H]1[C@H](Oc2cc(O)cc(O)c2C1=O)c1ccc(O)c(O)c1
# 514       579           Oc1ccc2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O
#
#     FP-2 IC50 (uM) FP-2 inhibition rate at 10 uM (%)  \
# 0              6.6                               NaN
# 1            >12.5                               NaN
# 2             39.1                               NaN
# 3              >33                               NaN
# 4              >33                               NaN
# ..             ...                               ...
# 510            0.1                              76.4
# 511            0.3                              75.8
# 512            0.2                              79.9
# 513            NaN                              16.9
# 514            0.3                              67.8
#
#      FP-2 inhibition rate at 20 uM (%)
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 510                                NaN
# 511                                NaN
# 512                                NaN
# 513                                NaN
# 514                                NaN
#
# [515 rows x 5 columns]

# %%
raw_data.isna().sum()
# Out:
# Compound                               0
# SMILE                                  0
# FP-2 IC50 (uM)                        66
# FP-2 inhibition rate at 10 uM (%)    422
# FP-2 inhibition rate at 20 uM (%)    502
# dtype: int64

# %%
raw_data.dtypes
# Out:
# Compound                               int64
# SMILE                                 object
# FP-2 IC50 (uM)                        object
# FP-2 inhibition rate at 10 uM (%)     object
# FP-2 inhibition rate at 20 uM (%)    float64
# dtype: object

# %% [markdown]
# ## Cleaning Raw Data

# %%
smiles_ic50 = raw_data.drop(["FP-2 inhibition rate at 10 uM (%)", "FP-2 inhibition rate at 20 uM (%)"], axis=1)
smiles_ic50
# Out:
#      Compound                                             SMILE FP-2 IC50 (uM)
# 0           2    OCCCc1sc(\C=C\C(=O)CSCCCc2ccccc2)nc1CCc1ccccc1            6.6
# 1           3       OCCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1          >12.5
# 2           4      O=CCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1           39.1
# 3           5   CC(=O)OCc1nc(CCC(=O)CSCCCc2ccccc2)sc1CCc1ccccc1            >33
# 4           6   NC(=O)CCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1            >33
# ..        ...                                               ...            ...
# 510       575     Oc1cc(O)c2c(c1)oc(-c1cc(O)c(O)c(O)c1)c(O)c2=O            0.1
# 511       576        Oc1cc(O)c2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O            0.3
# 512       577          Oc1ccc(c(O)c1)-c1oc2cc(O)cc(O)c2c(=O)c1O            0.2
# 513       578  O[C@@H]1[C@H](Oc2cc(O)cc(O)c2C1=O)c1ccc(O)c(O)c1            NaN
# 514       579           Oc1ccc2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O            0.3
#
# [515 rows x 3 columns]

# %%
smiles_ic50.isna().sum()
# Out:
# Compound           0
# SMILE              0
# FP-2 IC50 (uM)    66
# dtype: int64

# %%
smiles_ic50_no_nan = smiles_ic50.dropna(axis=0, how='any')
smiles_ic50_no_nan
# Out:
#      Compound                                            SMILE FP-2 IC50 (uM)
# 0           2   OCCCc1sc(\C=C\C(=O)CSCCCc2ccccc2)nc1CCc1ccccc1            6.6
# 1           3      OCCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1          >12.5
# 2           4     O=CCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1           39.1
# 3           5  CC(=O)OCc1nc(CCC(=O)CSCCCc2ccccc2)sc1CCc1ccccc1            >33
# 4           6  NC(=O)CCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1            >33
# ..        ...                                              ...            ...
# 509       574            Oc1ccc(cc1)-c1oc2cc(O)cc(O)c2c(=O)c1O            0.2
# 510       575    Oc1cc(O)c2c(c1)oc(-c1cc(O)c(O)c(O)c1)c(O)c2=O            0.1
# 511       576       Oc1cc(O)c2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O            0.3
# 512       577         Oc1ccc(c(O)c1)-c1oc2cc(O)cc(O)c2c(=O)c1O            0.2
# 514       579          Oc1ccc2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O            0.3
#
# [449 rows x 3 columns]

# %%
smiles_ic50_no_nan.loc[smiles_ic50_no_nan["FP-2 IC50 (uM)"].str.contains('>|-', regex=True)]
# Out:
#      Compound                                              SMILE  \
# 1           3        OCCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 3           5    CC(=O)OCc1nc(CCC(=O)CSCCCc2ccccc2)sc1CCc1ccccc1
# 4           6    NC(=O)CCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 6           9          OCc1nc(CCC(=O)CSCCCc2ccccc2)sc1CCc1ccccc1
# 7          10  CC(=O)NCCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# ..        ...                                                ...
# 497       561  CC(=O)c1ccc(NC(=O)CSc2nnc(COc3ccc4cccnc4c3)n2-...
# 498       562  COc1ccc(cc1)C(=O)NNC(=O)CSc1nnc(COc2ccc3cccnc3...
# 499       563  COc1cccc(\C=N\NC(=O)C2=NN(Cc3ccc(Cl)cc3Cl)CC2)c1O
# 500       564  CC(NC(=O)COc1ccc2ccccc2c1)C(=O)N\N=C\c1cccc(Cl...
# 501       565      CCc1ccc(OCc2nnc(SCC(=O)Nc3cccc4ccccc34)o2)cc1
#
#     FP-2 IC50 (uM)
# 1            >12.5
# 3              >33
# 4              >33
# 6           >12.56
# 7              >33
# ..             ...
# 497            >50
# 498            >50
# 499            >50
# 500            >50
# 501            >50
#
# [135 rows x 3 columns]

# %%
print('Total rows without relative values:', 449 - 135)
# Out:
# Total rows without relative values: 314

# %% [markdown]
# ## Final SMILES dan IC50 data

# %%
smiles_ic50_cleaned = smiles_ic50_no_nan.drop(smiles_ic50_no_nan[smiles_ic50_no_nan["FP-2 IC50 (uM)"].str.contains('>|-', regex=True)].index, axis=0, inplace=False)
smiles_ic50_cleaned = smiles_ic50_cleaned.reset_index(drop=True)
smiles_ic50_cleaned['FP-2 IC50 (uM)'] = smiles_ic50_cleaned['FP-2 IC50 (uM)'].astype('float')
smiles_ic50_cleaned
# Out:
#      Compound                                              SMILE  \
# 0           2     OCCCc1sc(\C=C\C(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 1           4       O=CCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 2           8  NC(=O)CCc1sc(NC(=O)CSCCCc2ccccc2)nc1\C=C\c1ccccc1
# 3          14                 CCCC\C(=N/NC(N)=S)c1ccc(Cl)c(Cl)c1
# 4          15             CC(C)(C)C(=N/NC(N)=S)\c1ccc(Cl)c(Cl)c1
# ..        ...                                                ...
# 309       574              Oc1ccc(cc1)-c1oc2cc(O)cc(O)c2c(=O)c1O
# 310       575      Oc1cc(O)c2c(c1)oc(-c1cc(O)c(O)c(O)c1)c(O)c2=O
# 311       576         Oc1cc(O)c2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O
# 312       577           Oc1ccc(c(O)c1)-c1oc2cc(O)cc(O)c2c(=O)c1O
# 313       579            Oc1ccc2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O
#
#      FP-2 IC50 (uM)
# 0              6.60
# 1             39.10
# 2             15.30
# 3              0.62
# 4              0.50
# ..              ...
# 309            0.20
# 310            0.10
# 311            0.30
# 312            0.20
# 313            0.30
#
# [314 rows x 3 columns]

# %%
smiles_ic50_cleaned.dtypes
# Out:
# Compound            int64
# SMILE              object
# FP-2 IC50 (uM)    float64
# dtype: object

# %%
smiles_ic50_cleaned.describe()
# Out:
#          Compound  FP-2 IC50 (uM)
# count  314.000000      314.000000
# mean   251.200637       17.740673
# std    157.478498       19.595276
# min      2.000000        0.000700
# 25%    112.250000        1.172500
# 50%    237.500000       10.000000
# 75%    362.750000       30.000000
# max    579.000000       90.700000

# %% [markdown]
# ## Convert IC50 values to pIC50 values for better data distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
### Convert IC50 values to pIC50 for better data distrubution
### original IC50 values are in micromolar(uM)(10^-6 mol/L)

def to_pic50(x):
    return -np.log10(x*(10**(-6)))

# %%
smiles_ic50_cleaned['FP-2 pIC50 (uM)'] = to_pic50(smiles_ic50_cleaned['FP-2 IC50 (uM)'])
smiles_ic50_cleaned
# Out:
#      Compound                                              SMILE  \
# 0           2     OCCCc1sc(\C=C\C(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 1           4       O=CCCc1sc(CCC(=O)CSCCCc2ccccc2)nc1CCc1ccccc1
# 2           8  NC(=O)CCc1sc(NC(=O)CSCCCc2ccccc2)nc1\C=C\c1ccccc1
# 3          14                 CCCC\C(=N/NC(N)=S)c1ccc(Cl)c(Cl)c1
# 4          15             CC(C)(C)C(=N/NC(N)=S)\c1ccc(Cl)c(Cl)c1
# ..        ...                                                ...
# 309       574              Oc1ccc(cc1)-c1oc2cc(O)cc(O)c2c(=O)c1O
# 310       575      Oc1cc(O)c2c(c1)oc(-c1cc(O)c(O)c(O)c1)c(O)c2=O
# 311       576         Oc1cc(O)c2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O
# 312       577           Oc1ccc(c(O)c1)-c1oc2cc(O)cc(O)c2c(=O)c1O
# 313       579            Oc1ccc2c(c1)oc(-c1ccc(O)c(O)c1)c(O)c2=O
#
#      FP-2 IC50 (uM)  FP-2 pIC50 (uM)
# 0              6.60         5.180456
# 1             39.10         4.407823
# 2             15.30         4.815309
# 3              0.62         6.207608
# 4              0.50         6.301030
# ..              ...              ...
# 309            0.20         6.698970
# 310            0.10         7.000000
# 311            0.30         6.522879
# 312            0.20         6.698970
# 313            0.30         6.522879
#
# [314 rows x 4 columns]

# %% [markdown]
# ## Export SMILES data to .smi format for calculating descriptor

# %%
smiles_ic50_cleaned["SMILE"].to_csv("Dataset Falcipain/falcipain_inhibitor.smi", index=False, header=False)
